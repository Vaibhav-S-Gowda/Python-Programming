# %% [markdown]
# # Reading  the Dataset

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("fruits.csv")
data.head()
# Out:
#    Weight  Size   Class
# 0      69  4.39  orange
# 1      69  4.21  orange
# 2      65  4.09  orange
# 3      72  5.85   apple
# 4      67  4.70  orange

# %% [markdown]
# ### Encoding the Categorical variable

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data.Class = le.fit_transform(data.Class)
data.head()
# Out:
#    Weight  Size  Class
# 0      69  4.39      1
# 1      69  4.21      1
# 2      65  4.09      1
# 3      72  5.85      0
# 4      67  4.70      1

# %% [markdown]
# ### Kernel Tricks

# %%
from sklearn.svm import LinearSVC, SVC

X = data.iloc[:, 0:2]
y = data.Class

lin_svc = LinearSVC().fit(X, y)

svc_lin = SVC(kernel = 'linear').fit(X, y)

rbf_svc = SVC(kernel = 'rbf').fit(X, y)

poly_svc3 = SVC(kernel = 'poly', degree = 3).fit(X, y)

poly_svc4 = SVC(kernel = 'poly', degree = 4).fit(X, y)

# %% [markdown]
# ### Model Score

# %%
print("Linear SVC Score: ",lin_svc.score(X, y))
print("SVC Linear Score: ", svc_lin.score(X, y))
print("RBF SVC Score: ", rbf_svc.score(X, y))
print("3 Degree Polynomial SVC Score: ", poly_svc3.score(X, y))
print("4 Degree Polynomial SVC Score: ", poly_svc4.score(X, y))
# Out:
# Linear SVC Score:  0.9
# SVC Linear Score:  1.0
# RBF SVC Score:  0.975
# 3 Degree Polynomial SVC Score:  0.925
# 4 Degree Polynomial SVC Score:  0.925

# %% [markdown]
# ### Plotting the decision boundaries

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(np.array(X), y.values, lin_svc)
# Out:
# C:\Users\vaibh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearSVC was fitted with feature names
#   The input samples.
# <Axes: >

# %%
plot_decision_regions(np.array(X), y.values, svc_lin)
# Out:
# C:\Users\vaibh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   The input samples.
# <Axes: >

# %%
plot_decision_regions(np.array(X), y.values, rbf_svc)
# Out:
# C:\Users\vaibh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   The input samples.
# <Axes: >

# %%
plot_decision_regions(np.array(X), y.values, poly_svc3)
plot_decision_regions(np.array(X), y.values, poly_svc4)
# Out:
# C:\Users\vaibh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   The input samples.
# C:\Users\vaibh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   The input samples.
# <Axes: >
